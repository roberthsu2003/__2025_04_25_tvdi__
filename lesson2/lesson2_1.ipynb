# %% [markdown]
# ### 呼叫function

# %%
def menu(wine:str, entree:str, dessert:str)->dict:
    return {"wine":wine,
            "entree":entree, 
            "desert":dessert}

# %%
#引數值的呼叫(依照順序)
menu('白酒', '牛排', '蛋糕')
#menu('白酒', '牛排') 錯誤
# Out:
# wine 白酒 entree 牛排 desert 蛋糕
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #引數值的呼叫(依照順序)
#       2 menu('白酒', '牛排', '蛋糕')
# ----> 3 menu('白酒', '牛排')
#
# TypeError: menu() missing 1 required positional argument: 'dessert'

# %%
pk:dict = menu("白酒","牛排","蛋糕")
pk
# Out:
# {'wine': '白酒', 'entree': '牛排', 'desert': '蛋糕'}
